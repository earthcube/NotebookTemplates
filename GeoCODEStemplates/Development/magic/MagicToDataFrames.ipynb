# %% [markdown]
# # Unpack MagIC database text file into Pandas dataframes
#
# This notebook should be saved as MagicToDataFrames.py if any changes are made. The python is then imported into the PmagPy_AnalysisFromWebCall notebook.
# Code is modified from code at https://github.com/PmagPy/PmagPy in ipmag.py and pmag.py modules (Licensed under a 3-clause BSD license. See [license.txt](https://github.com/ltauxe/PmagPy/blob/master/license.txt) for details.).
# Modifed and adapted by Stephen M. Richard 2019-06-06

# %%
#imports
import pandas as pd
import requests

# %%
def magicToDataframe(data_model=3.0, txt=""):
    """
    takes the name of a text file downloaded from the MagIC database and
    unpacks it into a dictionary of pandas dataframes. Each dataframe is named
    for the tab heading in the MagIC database file.
    Parameters
    ----------
    infile : str
        MagIC-format file to unpack
   
    txt : str, default ""
        if infile is not provided, you may provide a string with file contents instead
        (useful for downloading MagIC file directly from earthref)
        
    returns a dictionary 
    
    """
    infile=None
    framedict = {}
    
    if data_model == 2.5:
        method_col = "magic_method_codes"
    else:
        method_col = "method_codes"
    
    if txt:
        infile = txt.split("\n")
    else:
        print("no input text provided")
        return(framedict)
    
    
    File = []  # will contain all non-blank lines from downloaded file
    for line in infile:
        line = line.replace('\n', '')
        if line[0:4] == '>>>>' or len(line.strip()) > 0:  # skip blank lines
            File.append(line)
    #print(File)
    #return(framedict)
    
    LN = 0  # tracks our progress iterating through File
    type_list = []
    filenum = 0
    while LN < len(File) - 1:
        line = File[LN]
        if ">>>>" in line:
            LN += 1
            continue
        file_type = line.split('\t')[1]
        file_type = file_type.lower()
        if file_type[-1] == "\n":
            file_type = file_type[:-1]

        #print('working on: ', repr(file_type))
        if file_type not in type_list:
            type_list.append(file_type)
        else:
            filenum += 1
        LN += 1
        line = File[LN]
        # skip empty tables
        if line == ">>>>>>>>>>":
            LN += 1
            continue
        keys = line.replace('\n', '').split('\t')
        if keys[0][0] == '.':
            keys = line.replace('\n', '').replace('.', '').split('\t')
            keys.append('RecNo')  # cludge for new MagIC download format
        LN += 1
        Recs = []
        while LN < len(File):
            line = File[LN]
            # finish up one file type and then break
            if ">>>>" in line and len(Recs) > 0:
                
                NewRecs = []
                for rec in Recs:
                    if method_col in list(rec.keys()):
                        meths = rec[method_col].split(":")
                        if len(meths) > 0:
                            methods = ""
                            for meth in meths:
                                methods = methods + meth.strip() + ":"  # get rid of nasty spaces!!!!!!
                            rec[method_col] = methods[:-1]
                    NewRecs.append(rec)
                magic_writeDict(framedict, Recs, file_type)
                
                #print("Recs ", Recs)
                #print("data tab: ", file_type)
                Recs = []
                LN += 1
                break
            # keep adding records of the same file type
            else:
                rec = line.split('\t')
                Rec = {}
                if len(rec) == len(keys):
                    for k in range(len(rec)):
                        Rec[keys[k]] = rec[k]
                    Recs.append(Rec)
                # in case of magic_search_results.txt, which has an extra
                # column:
                elif len(rec) - len(keys) == 1:
                    for k in range(len(rec))[:-1]:
                        Rec[keys[k]] = rec[k]
                    Recs.append(Rec)
                elif len(rec) < len(keys):
                    for k in range(len(rec)):
                        Rec[keys[k]] = rec[k]
                    for k in range(len(rec), len(keys)):
                        Rec[keys[k]] = ""
                    Recs.append(Rec)
                else:
                    print('WARNING:  problem in file with line: ')
                    print(line)
                    print('skipping....')
                LN += 1
    if len(Recs) > 0:

        NewRecs = []
        for rec in Recs:
            if method_col in list(rec.keys()):
                meths = rec[method_col].split(":")
                if len(meths) > 0:
                    methods = ""
                    for meth in meths:
                        methods = methods + meth.strip() + ":"  # get rid of nasty spaces!!!!!!
                    rec[method_col] = methods[:-1]
            NewRecs.append(rec)
        magic_writeDict(framedict,Recs, file_type)
        #print("Recs /n", Recs)
        #print("data tab: ", file_type)
  
    return framedict

# %%
def download_from_magic(con_id):
    """
    Download a MagIC contribution directly from the MagIC API.
    If successful, this will write individual MagIC files to
    your chosen dir_path
    Parameters
    ----------
    con_id : number
        MagIC contribution id, i.e. 12366
    dir_path : str, default "."
        directory for outputting files
    Returns
    ---------
    bool : True or False indicating whether download was successful
    """
    if not requests:
        print('-W- You must install the requests module to use this functionality')
        return
    try:
        res = requests.get('https://earthref.org/MagIC/download/{}/'.format(con_id))
    except (requests.exceptions.ConnectTimeout, requests.exceptions.ConnectionError,
                requests.exceptions.ReadTimeout):
        print("-W- Could not connect to MagIC")
        return
    if not res.ok:
        print("-W- Could not connect to MagIC -- check your requested contribution id ({})".format(con_id))
        return
    resultframedict = {}
    print("CALL magicToDataframe")
    resultframedict = magicToDataframe(txt=res.text)
    
    #print some citation information for the source
    if not(resultframedict['contribution'].empty):
        thecontribs=resultframedict['contribution']
        thekeys=(list(thecontribs))
        for index, row in thecontribs.iterrows():
            if 'contributor' in thekeys:
                contrib = 'contributor: ' + row['contributor'] + '; '
            else:
                contrib = ''
            if 'author' in thekeys:
                auth = 'author: ' + row['author'] + '; '
            else:
                auth = ''

            if 'reference' in thekeys:
                refer = ' reference: ' + row['reference']
            else:
                refer = ''
            print(contrib + auth + refer)
        
        
    return resultframedict

# %%
def magic_writeDict(framedict, Recs, file_type):
    """
    Parameters
    _________
    framedict == the dictionary of frames. the key is file_type, values are pandas
        frame constructed from Recs
    Recs : list of dictionaries in MagIC format
    file_type : MagIC table type (e.g., specimens)
    Return :
    [True,False] : True if successful
    ofile : same as input
    Effects :
        writes a MagIC formatted file from Recs
    """
    if len(Recs) < 1:
        print('No records to write to file {}'.format(ofile))
        return False, ""
   # if os.path.split(ofile)[0] != "" and not os.path.isdir(os.path.split(ofile)[0]):
      #  os.mkdir(os.path.split(ofile)[0])
    #mag_out = open(ofile, 'w+', errors="backslashreplace")
    #print("file_type: ",file_type)
    framedict[file_type]=pd.DataFrame(Recs)
    #framedict[file_type]=Recs
    #print("framedict: ", framedict)

    print('data table: ' + file_type + '; ' + str(len(Recs)) + ' records')
    return True

# %%
#change from markdown to code for testing


outputdict = {}
outputdict = download_from_magic(12765)
print("output: ", outputdict)
# Out:
# CALL magicToDataframe
# data table: contribution; 1 records
# data table: locations; 6 records
# data table: sites; 345 records
# data table: samples; 1301 records
# data table: specimens; 667 records
# data table: measurements; 13395 records
# data table: ages; 89 records
# contributor: @polarwand;  reference: 10.1002/2013GC005180
# output:  {'contribution':       id version                 timestamp contributor data_model_version  \
# 0  12765       3  2016-02-08T10:35:52.000Z  @polarwand                3.0
#
#               reference                                        description
# 0  10.1002/2013GC005180  Upgraded to MagIC Data Model 3.0 by the MagIC ...  , 'locations':          location location_type           result_name result_type  \
# 0  Simpson Island  Land Section   lower third SI pole           i
# 1  Simpson Island  Land Section   lower third SI pole           i
# 2  Simpson Island  Land Section  middle third SI pole           i
# 3  Simpson Island  Land Section  middle third SI pole           i
# 4  Simpson Island  Land Section   upper third SI pole           i
# 5  Simpson Island  Land Section   upper third SI pole           i
#
#   method_codes   citations plate_blocks    lat_s    lat_n     lon_w  ...  \
# 0      DE-POLE  This study    Laurentia  48.7363  48.8122  272.3038  ...
# 1      DE-POLE  This study    Laurentia  48.7363  48.8122  272.3038  ...
# 2      DE-POLE  This study    Laurentia  48.7363  48.8122  272.3038  ...
# 3      DE-POLE  This study    Laurentia  48.7363  48.8122  272.3038  ...
# 4      DE-POLE  This study    Laurentia  48.7363  48.8122  272.3038  ...
# 5      DE-POLE  This study    Laurentia  48.7363  48.8122  272.3038  ...
#
#   age_high age_unit dir_tilt_correction dir_dec dir_inc dir_alpha95  \
# 0     1110       Ma                 100                         3.4
# 1     1110       Ma                  -3    99.3     -68
# 2     1110       Ma                 100                         5.5
# 3     1110       Ma                  -3   105.9   -64.9
# 4     1110       Ma                 100                         3.5
# 5     1110       Ma                  -3   107.6   -61.6
#
#   dir_n_samples pole_lat pole_lon pole_alpha95
# 0            30     40.9    218.6          4.8
# 1                   40.9    218.6          4.8
# 2            20     42.7    211.3          8.2
# 3                   42.7    211.3          8.2
# 4            34     41.6    205.4          4.8
# 5                   41.6    205.4          4.8
#
# [6 rows x 25 columns], 'sites':                     site        location  \
# 0      SI1(11.8 to 26.4)  Simpson Island
# 1      SI1(11.8 to 26.4)  Simpson Island
# 2      SI1(11.8 to 26.4)  Simpson Island
# 3      SI1(11.8 to 26.4)  Simpson Island
# 4    SI1(116.3 to 118.8)  Simpson Island
# ..                   ...             ...
# 340    SI9(84.0 to 88.9)  Simpson Island
# 341           SI9(D1-D9)  Simpson Island
# 342           SI9(D1-D9)  Simpson Island
# 343      SI9(D10 to D18)  Simpson Island
# 344      SI9(D10 to D18)  Simpson Island
#
#                                                samples  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 340
# 341
# 342  SI9-D1:SI9-D2:SI9-D3:SI9-D4:SI9-D5:SI9-D6:SI9-...
# 343
# 344  SI9-D10:SI9-D11:SI9-D12:SI9-D13:SI9-D14:SI9-D1...
#
#                                              specimens result_type  \
# 0
# 1                                                                i
# 2                                                                i
# 3                                                                i
# 4
# ..                                                 ...         ...
# 340                                                              i
# 341
# 342  SI9-D1a:SI9-D2a:SI9-D3a:SI9-D4a:SI9-D6a:SI9-D7...
# 343
# 344  SI9-D10a:SI9-D11a:SI9-D12a:SI9-D13a:SI9-D14a:S...
#
#     result_quality                   method_codes   citations  \
# 0                                        GE-WGS84  This study
# 1                   DE-BFL:DE-FM:LP-DC4:LP-DIR-AF  This study
# 2                   DE-BFL:DE-FM:LP-DC4:LP-DIR-AF  This study
# 3                   DE-BFL:DE-FM:LP-DC4:LP-DIR-AF  This study
# 4                                        GE-WGS84  This study
# ..             ...                            ...         ...
# 340                 DE-BFL:DE-FM:LP-DC4:LP-DIR-AF  This study
# 341                                      GE-WGS84  This study
# 342              g               LP-DC4:LP-DIR-AF  This study
# 343                                      GE-WGS84  This study
# 344              g               LP-DC4:LP-DIR-AF  This study
#
#         geologic_classes geologic_types  ... age_unit dir_tilt_correction  \
# 0     Igneous:Extrusive       Lava Flow  ...
# 1                                        ...       Ma                 100
# 2                                        ...       Ma                  -3
# 3                                        ...       Ma                   0
# 4     Igneous:Extrusive       Lava Flow  ...
# ..                   ...            ...  ...      ...                 ...
# 340                                      ...       Ma                   0
# 341   Igneous:Intrusive            Dike  ...
# 342                                      ...
# 343   Igneous:Intrusive            Dike  ...
# 344                                      ...
#
#     dir_dec dir_inc dir_alpha95 dir_polarity dir_nrm_origin vgp_lat vgp_lon  \
# 0
# 1      79.7   -70.5         2.7            n              p    33.1   229.6
# 2      79.7   -70.5                        n              p    33.1   229.6
# 3     120.3   -77.1                        n              p    33.1   229.6
# 4
# ..      ...     ...         ...          ...            ...     ...     ...
# 340   104.7   -76.7                        n              p    19.1   244.4
# 341
# 342
# 343
# 344
#
#            description
# 0
# 1    SI1(11.8 to 26.4)
# 2    SI1(11.8 to 26.4)
# 3    SI1(11.8 to 26.4)
# 4
# ..                 ...
# 340  SI9(84.0 to 88.9)
# 341
# 342
# 343
# 344
#
# [345 rows x 29 columns], 'samples':           sample                 site    specimens result_quality  \
# 0      SI1-116.9  SI1(116.3 to 118.8)
# 1      SI1-116.9  SI1(116.3 to 118.8)   SI1-116.9a              g
# 2     SI1-116.95  SI1(116.3 to 118.8)
# 3     SI1-116.95  SI1(116.3 to 118.8)  SI1-116.95a              g
# 4     SI1-116.96  SI1(116.3 to 118.8)
# ...          ...                  ...          ...            ...
# 1296      SI9-D7           SI9(D1-D9)      SI9-D7a              g
# 1297      SI9-D8           SI9(D1-D9)
# 1298      SI9-D8           SI9(D1-D9)      SI9-D8a              g
# 1299      SI9-D9           SI9(D1-D9)
# 1300      SI9-D9           SI9(D1-D9)      SI9-D9a              g
#
#                    method_codes   citations     geologic_classes  \
# 0     FS-FD:SO-CMD-NORTH:SO-POM  This study   Extrusive:Igneous
# 1                        DE-BFL  This study
# 2     FS-FD:SO-CMD-NORTH:SO-POM  This study   Extrusive:Igneous
# 3                        DE-BFL  This study
# 4     FS-FD:SO-CMD-NORTH:SO-POM  This study   Extrusive:Igneous
# ...                         ...         ...                  ...
# 1296                     DE-BFL  This study
# 1297  FS-FD:SO-CMD-NORTH:SO-POM  This study   Igneous:Intrusive
# 1298                     DE-BFL  This study
# 1299  FS-FD:SO-CMD-NORTH:SO-POM  This study   Igneous:Intrusive
# 1300                     DE-BFL  This study
#
#      geologic_types lithologies orientation_quality  ...      lat       lon  \
# 0         Lava Flow      Basalt                   g  ...  48.8062  272.3366
# 1                                                    ...
# 2         Lava Flow      Basalt                   g  ...  48.8062  272.3366
# 3                                                    ...
# 4         Lava Flow      Basalt                   g  ...  48.8062  272.3366
# ...             ...         ...                 ...  ...      ...       ...
# 1296                                                 ...
# 1297           Dike     Diabase                   g  ...  48.7718  272.3779
# 1298                                                 ...
# 1299           Dike     Diabase                   g  ...  48.7718  272.3779
# 1300                                                 ...
#
#      dir_tilt_correction dir_dec dir_inc dir_n_specimens  \
# 0
# 1                    100    73.0   -72.7               1
# 2
# 3                    100    56.8   -66.2               1
# 4
# ...                  ...     ...     ...             ...
# 1296                 100    87.2   -49.4               1
# 1297
# 1298                 100   110.8   -46.3               1
# 1299
# 1300                 100    88.5   -32.5               1
#
#      dir_n_specimens_lines dir_polarity dir_nrm_origin    description
# 0                                                       oriented core
# 1                        1            n              p
# 2                                                       oriented core
# 3                        1            n              p
# 4                                                       oriented core
# ...                    ...          ...            ...            ...
# 1296                     1            n              p
# 1297                                                    oriented core
# 1298                     1            n              p
# 1299                                                    oriented core
# 1300                     1            n              p
#
# [1301 rows x 22 columns], 'specimens':         specimen      sample result_quality  \
# 0    SI1-116.95a  SI1-116.95              g
# 1    SI1-116.96a  SI1-116.96              g
# 2    SI1-116.97a  SI1-116.97              g
# 3     SI1-116.9a   SI1-116.9              g
# 4    SI1-117.05a  SI1-117.05              g
# ..           ...         ...            ...
# 662      SI9-D4a      SI9-D4              g
# 663      SI9-D6a      SI9-D6              g
# 664      SI9-D7a      SI9-D7              g
# 665      SI9-D8a      SI9-D8              g
# 666      SI9-D9a      SI9-D9              g
#
#                            method_codes   citations meas_step_min  \
# 0    DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study          0.06
# 1    DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study          0.02
# 2    DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study          0.03
# 3    DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study          0.06
# 4    DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study          0.02
# ..                                  ...         ...           ...
# 662  DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study         0.005
# 663  DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study         0.003
# 664  DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study         0.015
# 665  DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study         0.005
# 666  DA-DIR-GEO:DE-BFL:LP-DC4:LP-DIR-AF  This study          0.01
#
#     meas_step_max meas_step_unit     geologic_classes geologic_types  \
# 0            0.17              T   Extrusive:Igneous       Lava Flow
# 1            0.07              T   Extrusive:Igneous       Lava Flow
# 2            0.09              T   Extrusive:Igneous       Lava Flow
# 3            0.07              T   Extrusive:Igneous       Lava Flow
# 4            0.07              T   Extrusive:Igneous       Lava Flow
# ..            ...            ...                  ...            ...
# 662           0.1              T   Igneous:Intrusive            Dike
# 663           0.1              T   Igneous:Intrusive            Dike
# 664          0.05              T   Igneous:Intrusive            Dike
# 665          0.04              T   Igneous:Intrusive            Dike
# 666          0.04              T   Igneous:Intrusive            Dike
#
#     lithologies dir_tilt_correction dir_dec dir_inc dir_n_measurements  \
# 0        Basalt                 100    56.8   -66.2                  8
# 1        Basalt                 100    90.7   -68.9                  7
# 2        Basalt                 100    53.7   -65.0                  7
# 3        Basalt                 100    73.0   -72.7                  7
# 4        Basalt                 100    76.8   -75.5                  7
# ..          ...                 ...     ...     ...                ...
# 662     Diabase                 100    88.9   -61.3                 14
# 663     Diabase                 100    88.0   -64.3                 15
# 664     Diabase                 100    87.2   -49.4                  6
# 665     Diabase                 100   110.8   -46.3                  8
# 666     Diabase                 100    88.5   -32.5                  6
#
#     dir_polarity dir_nrm_origin dir_mad_free
# 0              n              p          4.8
# 1              n              p          0.5
# 2              n              p          1.5
# 3              n              p          0.9
# 4              n              p          0.3
# ..           ...            ...          ...
# 662            n              p          1.1
# 663            n              p          0.6
# 664            n              p          2.2
# 665            n              p          2.5
# 666            n              p          3.2
#
# [667 rows x 18 columns], 'measurements':       treat_ac_field       method_codes measurement standard treat_temp  \
# 0                  0    LT-NO:LP-DIR-AF      756528        u        300
# 1                  0    LT-NO:LP-DIR-AF      756529        u        300
# 2                  0    LT-NO:LP-DIR-AF      756530        u        300
# 3                  0    LT-NO:LP-DIR-AF      756531        u        300
# 4                  0    LT-NO:LP-DIR-AF      756532        u        300
# ...              ...                ...         ...      ...        ...
# 13390           0.17  LT-AF-Z:LP-DIR-AF     1166903        u        300
# 13391           0.17  LT-AF-Z:LP-DIR-AF     1166904        u        300
# 13392           0.17  LT-AF-Z:LP-DIR-AF     1166905        u        300
# 13393           0.17  LT-AF-Z:LP-DIR-AF     1166906        u        300
# 13394           0.17  LT-AF-Z:LP-DIR-AF     1166907        u        300
#
#                   timestamp       dir_dec   citations  \
# 0      2011-08-06T17:44:03Z   46.14940858  This study
# 1      2011-08-06T17:44:19Z  347.45825787  This study
# 2      2011-08-06T17:44:34Z   31.61130498  This study
# 3      2011-08-06T17:44:49Z  346.74586067  This study
# 4      2011-08-06T17:45:04Z   22.60993981  This study
# ...                     ...           ...         ...
# 13390  2012-12-10T18:47:19Z  306.69724504  This study
# 13391  2012-12-10T18:47:34Z  318.28220966  This study
# 13392  2012-12-10T18:47:49Z   0.248670585  This study
# 13393  2012-12-10T18:48:04Z  349.51244064  This study
# 13394  2012-12-10T18:48:19Z  320.57903766  This study
#
#                           experiment       dir_inc quality     specimen  \
# 0       SI1-12.5-D:NRM_demag(T,Hac)0  -5.499271066       g   SI1-12.5-D
# 1      SI1-12.55-D:NRM_demag(T,Hac)0  -31.12430153       g  SI1-12.55-D
# 2       SI1-13.0-D:NRM_demag(T,Hac)0  -14.94022605       g   SI1-13.0-D
# 3       SI1-13.4-D:NRM_demag(T,Hac)0  -47.01666564       g   SI1-13.4-D
# 4       SI1-14.2-D:NRM_demag(T,Hac)0  -48.74651286       g   SI1-14.2-D
# ...                              ...           ...     ...          ...
# 13390      SI9-D4a:NRM_demag(T,Hac)0  -7.443149516       g      SI9-D4a
# 13391      SI9-D6a:NRM_demag(T,Hac)0   20.73683825       g      SI9-D6a
# 13392      SI9-D7a:NRM_demag(T,Hac)0   7.870728072       g      SI9-D7a
# 13393      SI9-D8a:NRM_demag(T,Hac)0   9.866069608       g      SI9-D8a
# 13394      SI9-D9a:NRM_demag(T,Hac)0   -6.92760056       g      SI9-D9a
#
#       magn_moment meas_pos_z
# 0        2.52E-06      0.067
# 1        1.70E-05      0.267
# 2        2.59E-06      0.467
# 3        6.56E-06      0.667
# 4        3.86E-06      0.867
# ...           ...        ...
# 13390    4.59E-08       0.67
# 13391    7.15E-08       0.87
# 13392    5.36E-08       1.07
# 13393    1.02E-07       1.27
# 13394    3.98E-08       1.47
#
# [13395 rows x 14 columns], 'ages':           location                 site   age age_unit   citations
# 0   Simpson Island    SI1(11.8 to 26.4)  1105       Ma  This study
# 1   Simpson Island  SI1(116.3 to 118.8)  1105       Ma  This study
# 2   Simpson Island  SI1(119.7 to 122.1)  1105       Ma  This study
# 3   Simpson Island  SI1(122.1 to 123.7)  1105       Ma  This study
# 4   Simpson Island    SI1(28.3 to 29.2)  1105       Ma  This study
# ..             ...                  ...   ...      ...         ...
# 84  Simpson Island  SI9(395.3 to 399.3)  1105       Ma  This study
# 85  Simpson Island    SI9(66.9 to 84.0)  1105       Ma  This study
# 86  Simpson Island    SI9(84.0 to 88.9)  1105       Ma  This study
# 87  Simpson Island           SI9(D1-D9)  1105       Ma  This study
# 88  Simpson Island      SI9(D10 to D18)  1105       Ma  This study
#
# [89 rows x 5 columns]}

# %%
#change from markdown to code for testing


if not(outputdict['contribution'].empty):
    thecontribs=outputdict['contribution']
    thekeys=(list(thecontribs))
    for index, row in thecontribs.iterrows():
        if 'contributor' in thekeys:
            contrib = 'contributor: ' + row['contributor'] + '; '
        else:
            contrib = ''
        if 'author' in thekeys:
            auth = 'author: ' + row['author'] + '; '
        else:
            auth = ''
        
        if 'reference' in thekeys:
            refer = ' reference: ' + row['reference']
        else:
            refer = ''
        
        if 'data_model_version' in thekeys:
            dm = ' data_model_version: ' + row['data_model_version']
        else:
            dm = ''
        
        
            
            
            
        print(contrib + auth + refer + dm)
# Out:
# contributor: @polarwand;  reference: 10.1002/2013GC005180 data_model_version: 3.0
